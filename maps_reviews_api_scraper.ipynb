# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-matos/maps-reviews-api-scraper/blob/master/maps_reviews_api_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/emerson-matos/maps-reviews-api-scraper
# Out:
# Cloning into 'maps-reviews-api-scraper'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 212 (delta 120), reused 160 (delta 73), pack-reused 0
# Receiving objects: 100% (212/212), 168.18 KiB | 4.43 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd maps-reviews-api-scraper
# Out:
# /content/maps-reviews-api-scraper

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 4.1 MB/s eta 0:00:00
# ...

# %%
# !python -m app run-async --path /content/gdrive/MyDrive/tcc/input/hotels.csv
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 2023-02-15 03:53:28,463 INFO    502 [scrape_reviews] (scraper.py:394): Pratagy Beach Al - Request:     1000; review:    10000
# 2023-02-15 03:53:28,614 INFO    503 [scrape_reviews] (scraper.py:394): Sol Barra Hotel  - Request:      168; review:     1680
# 2023-02-15 03:53:28,870 INFO    499 [scrape_reviews] (scraper.py:394): Prive Riviera Pa - Request:      918; review:     9180
# 2023-02-15 03:53:28,897 INFO    498 [scrape_reviews] (scraper.py:394): Iberostar Bahia  - Request:     1424; review:    14240
# 2023-02-15 03:53:28,983 INFO    500 [scrape_reviews] (scraper.py:394): SERHS Natal Gran - Request:      433; review:     4330
# 2023-02-15 03:53:29,032 INFO    501 [scrape_reviews] (scraper.py:394): Transamerica Com - Request:      150; review:     1500
# 2023-02-15 03:53:29,164 INFO    497 [scrape_reviews] (scraper.py:394): Sauípe Premium B - Request:      670; review:     6700
# ...

# %%
# %mv /content/maps-reviews-api-scraper/data /content/gdrive/MyDrive/tcc

# %%
# %mv /content/maps-reviews-api-scraper/errors /content/gdrive/MyDrive/tcc
